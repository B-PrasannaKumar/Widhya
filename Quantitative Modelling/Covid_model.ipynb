# %% [markdown]
# # TASK 3

# %%
import pandas as pd

# %%
covid_data = pd.read_csv('https://raw.githubusercontent.com/WidhyaOrg/datasets/master/covid19.csv')

# %%
covid_data
# Out:
#      Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0      1  30/01/20               Kerala                        1
# 1      2  31/01/20               Kerala                        1
# 2      3  01/02/20               Kerala                        2
# 3      4  02/02/20               Kerala                        3
# 4      5  03/02/20               Kerala                        3
# ..   ...       ...                  ...                      ...
# 265  266  21/03/20    Jammu and Kashmir                        4
# 266  267  21/03/20               Ladakh                       13
# 267  268  21/03/20        Uttar Pradesh                       23
# 268  269  21/03/20          Uttarakhand                        3
# 269  270  21/03/20          West Bengal                        3
#
#      ConfirmedForeignNational  Cured  Deaths
# 0                           0      0       0
# 1                           0      0       0
# 2                           0      0       0
# ...

# %%
date_data = covid_data.groupby(['Date'], sort=False).sum()

# %%
date_data.head()
# Out:
#           Sno  ConfirmedIndianNational  ConfirmedForeignNational  Cured  \
# Date
# 30/01/20    1                        1                         0      0
# 31/01/20    2                        1                         0      0
# 01/02/20    3                        2                         0      0
# 02/02/20    4                        3                         0      0
# 03/02/20    5                        3                         0      0
#
#           Deaths
# Date
# 30/01/20       0
# 31/01/20       0
# 01/02/20       0
# 02/02/20       0
# 03/02/20       0

# %%
date_data['totals'] = date_data['ConfirmedForeignNational'] + date_data['ConfirmedIndianNational'] + date_data['Cured'] + date_data['Deaths']

# %%
date_data
# Out:
#            Sno  ConfirmedIndianNational  ConfirmedForeignNational  Cured  \
# Date
# 30/01/20     1                        1                         0      0
# 31/01/20     2                        1                         0      0
# 01/02/20     3                        2                         0      0
# 02/02/20     4                        3                         0      0
# 03/02/20     5                        3                         0      0
# 04/02/20     6                        3                         0      0
# 05/02/20     7                        3                         0      0
# 06/02/20     8                        3                         0      0
# 07/02/20     9                        3                         0      0
# 08/02/20    10                        3                         0      0
# 09/02/20    11                        3                         0      0
# 10/02/20    12                        3                         0      0
# ...

# %%
answer = int(date_data.groupby('Date').get_group('04/03/20')['totals'])

# %%
import matplotlib.pyplot as plt

# %%
date_data.columns
# Out:
# Index(['Sno', 'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'totals'],
#       dtype='object')

# %%
x = date_data.reset_index()['Date']
y = date_data['totals']

# %%
plt.figure(figsize = (15,5))
plt.xlabel('Dates')
plt.ylabel('Total Cases')
plt.xticks(rotation = 90)
plt.plot(x,y)

# %% [markdown]
# # TASK 4

# %%
rate_change = date_data.reset_index()['totals'].pct_change()

# %%
date_data.reset_index()['totals'].pct_change()
# Out:
# 0          NaN
# 1     0.000000
# 2     1.000000
# 3     0.500000
# 4     0.000000
# 5     0.000000
# 6     0.000000
# 7     0.000000
# 8     0.000000
# 9     0.000000
# 10    0.000000
# 11    0.000000
# 12    0.000000
# 13    0.000000
# 14    0.000000
# 15    0.000000
# 16    0.000000
# 17    0.000000
# 18    0.000000
# 19    0.000000
# 20    0.000000
# 21    0.000000
# 22    0.000000
# 23    0.000000
# 24    0.000000
# 25    0.000000
# 26    0.000000
# 27    0.000000
# 28    0.000000
# 29    0.000000
# 30    0.000000
# 31    0.000000
# 32    0.666667
# 33    0.800000
# 34    2.444444
# 35    0.064516
# 36    0.030303
# 37    0.088235
# 38    0.135135
# 39    0.166667
# 40    0.244898
# 41    0.032787
# 42    0.222222
# 43    0.103896
# 44    0.129412
# 45    0.302083
# 46    0.032000
# 47    0.193798
# 48    0.090909
# 49    0.172619
# 50    0.269036
# 51    0.240000
# Name: totals, dtype: float64

# %%
rate_change.tail(18)
# Out:
# 34    2.444444
# 35    0.064516
# 36    0.030303
# 37    0.088235
# 38    0.135135
# 39    0.166667
# 40    0.244898
# 41    0.032787
# 42    0.222222
# 43    0.103896
# 44    0.129412
# 45    0.302083
# 46    0.032000
# 47    0.193798
# 48    0.090909
# 49    0.172619
# 50    0.269036
# 51    0.240000
# Name: totals, dtype: float64

# %%
rate_avg = rate_change.sum() / len(rate_change)

# %%
rate_avg
# Out:
# 0.15249284146323905

# %%
import math
p_t = 31 * (math.exp(rate_avg * 26))
print(p_t)
# Out:
# 1634.0241949959104
